# %%
import pandas as pd

df_population_raw = pd.read_csv('population_total.csv')
df_population_raw
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %%
#dropping null values
df_population_raw.dropna(inplace=True)

# %%
#making pivot table

df_pivot = df_population_raw.pivot(index= 'year', columns= 'country', values= 'population')

# %%
#selecting some countries

df_pivot = df_pivot[['United States', 'China', 'India', 'Indonesia', 'Brazil']]
df_pivot
# Out:
# country  United States         China         India    Indonesia       Brazil
# year
# 1955.0     171685336.0  6.122416e+08  4.098806e+08   77273425.0   62533919.0
# 1960.0     186720571.0  6.604081e+08  4.505477e+08   87751068.0   72179226.0
# 1965.0     199733676.0  7.242190e+08  4.991233e+08  100267062.0   83373530.0
# 1970.0     209513341.0  8.276014e+08  5.551898e+08  114793178.0   95113265.0
# 1975.0     219081251.0  9.262409e+08  6.231029e+08  130680727.0  107216205.0
# 1980.0     229476354.0  1.000089e+09  6.989528e+08  147447836.0  120694009.0
# 1985.0     240499825.0  1.075589e+09  7.843600e+08  164982451.0  135274080.0
# 1990.0     252120309.0  1.176884e+09  8.732778e+08  181413402.0  149003223.0
# 1995.0     265163745.0  1.240921e+09  9.639226e+08  196934260.0  162019896.0
# 2000.0     281710909.0  1.290551e+09  1.056576e+09  211513823.0  174790340.0
# 2005.0     294993511.0  1.330776e+09  1.147610e+09  226289470.0  186127103.0
# ...

# %%
#lineplot

df_pivot.plot(kind= 'line', xlabel= 'Year', ylabel= 'Population', title= 'Population (1955 - 2020)', figsize=(8,4))
# Out:
# <Axes: title={'center': 'Population (1955 - 2020)'}, xlabel='Year', ylabel='Population'>

# %%
#barplot single year

df_pivot_2020 = df_pivot[df_pivot.index.isin([2020])]
df_pivot_2020
# Out:
# country  United States         China         India    Indonesia       Brazil
# year
# 2020.0     331002651.0  1.439324e+09  1.380004e+09  273523615.0  212559417.0

# %%
#rows to columns/ viceversa

df_pivot_2020 = df_pivot_2020.T

# %%
#plotting barplot

df_pivot_2020.plot(kind='bar', xlabel= 'Country', ylabel= 'Population', title= 'Population 2020', color= 'red')
# Out:
# <Axes: title={'center': 'Population 2020'}, xlabel='Country', ylabel='Population'>

# %%
#barplot multiple years

df_pivot_sample = df_pivot[df_pivot.index.isin([1990, 2000, 2010, 2020])]

df_pivot_sample.plot(kind= 'bar', xlabel= 'Country', ylabel= 'Population')
# Out:
# <Axes: xlabel='Country', ylabel='Population'>

# %%
#piechart

df_pivot_2020.rename(columns= {2020:'2020'}, inplace=True)

df_pivot_2020.plot(kind= 'pie', y= '2020', title= 'Population in 2020(%)')
# Out:
# <Axes: title={'center': 'Population in 2020(%)'}, ylabel='2020'>
